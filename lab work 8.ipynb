# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\somic\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\somic\anaconda3\lib\site-packages (from scipy) (1.21.5)

# %%
from scipy import interpolate
import numpy as np
import matplotlib.pyplot as plt

# %%
#def cubicinterpolation():
x_pts = np.linspace(0,2*np.pi,10) # 10 equidistant coords from 0 to 10
y_pts = np.sin(x_pts)
x_vals = np.linspace(0,2*np.pi,50) # 50 desired parts
    
splines = interpolate.splrep(x_pts,y_pts)
y_vals = interpolate.splev(x_vals,splines) #cubic interpolation
    
plt.plot(x_pts,y_pts,'r') # plot known data points
plt.plot(x_vals,y_vals,'x') # plot interpolated points
plt.show()

# %%
#def cubicinterpolation1():
x_pts = np.linspace(0,2*np.pi,10) # 10 equidistant coords from 0 to 10
y_pts = np.sin(x_pts)
x_vals = np.linspace(0,2*np.pi,50) # 50 desired parts
    
f = interpolate.interp1d(x_pts,y_pts,'cubic')
y_vals = f(x_vals) # cubic interpolation
    
plt.plot(x_pts,y_pts,'g') # plot known data points
plt.plot(x_vals,y_vals,'x') # plot interpolated points
plt.show()
